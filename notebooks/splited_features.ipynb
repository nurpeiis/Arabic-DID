# %%
import os
import pandas as pd

# %%
def init_count(a, folder):
    options = ['train', 'dev', 'test']
    a[folder] = dict()
    for option in options:
        a[folder][option] = 0
    return a

def init_set(a, folder):
    options = ['train', 'dev', 'test']
    a[folder] = dict()
    for option in options:
        a[folder][option] = set()
    return a

def append_set(parent_set, child_set):
    for child in child_set:
        parent_set.add(child)
    return parent_set

# %%
parent_dir = '../../hierarchical-did/data_processed_second/'
folders = ['ldc_callhome_arabic_trans_1997_t19']
word_count = dict()
char_count = dict()
word_set = dict()
char_set = dict()
lines_count = dict()
for folder in folders:
    word_count = init_count(word_count, folder)
    char_count = init_count(char_count, folder)
    word_set = init_set(word_set, folder)
    char_set = init_set(word_set, folder)
    lines_count = init_count(lines_count, folder)
    
    files = os.listdir(parent_dir+folder)
    print(f'Doing {folder}')
    
    for file in files:
        if 'info_data' in file or 'Store' in file:
            continue
        print(f'------- {file}')
        df = pd.read_csv(f'{parent_dir}{folder}/{file}', sep='\t', header=0)
        l_count = len(df.index)
        w_count = 0
        w_set = set()
        c_count = 0
        c_set = set()
        
        for index, row in df.iterrows():
            sentence = row['original_sentence']
            words = sentence.split(' ')
            for w in words:
                w_set.add(w)
            w_count += len(words)
            
            chars = list(sentence)
            for c in chars:
                c_set.add(c)
            c_count += len(chars)
        type_file = None
        if 'train' in file:
            type_file = 'train'
        elif 'dev' in file:
            type_file = 'dev'
        elif 'test' in file:
            type_file = 'test'
        
        lines_count[folder][type_file] += l_count
        word_count[folder][type_file] += w_count
        char_count[folder][type_file] += c_count
        word_set[folder][type_file] = append_set(word_set[folder][type_file], w_set)
        char_set[folder][type_file] = append_set(char_set[folder][type_file], c_set)
# Out:
# Doing ldc_callhome_arabic_trans_1997_t19
# ------- test_processed.lines
# ------- train_processed.lines
# ------- dev_processed.lines

# %%
options = ['train', 'dev', 'test']

def get_set_count(set_count):
    count = dict()
    
    for k in set_count.keys():
        count[k] = dict()
        total = 0
        for option in options:
            c = len(set_count[k][option])
            count[k][option] = c
            total += c
        count[k]['total'] = total
    
    return count
def get_total_count(count):
    for k in count.keys():
        total = 0
        for option in options:
            c = count[k][option]
            total += c
        count[k]['total'] = total 
    
    return count

# %%
lines_count = get_total_count(lines_count)
word_count = get_total_count(word_count)
char_count = get_total_count(char_count)
word_set_count = get_set_count(word_set)
char_set_count = get_set_count(char_set)

# %%
df = pd.read_csv('../datasets_splited_features.tsv', sep='\t', header=0)
df['dataset_name']
df.loc[17,'dataset_name']  = 'multi_dialect_multi_genre_informal_corpus_news'
df.loc[18,'dataset_name']  = 'multi_dialect_multi_genre_informal_corpus_twitter'
df.loc[19,'dataset_name']  = 'ldc_callhome_arabic_trans_1997_t19'
df
# Out:
#                                          dataset_name  \
# 0                                                 aoc
# 1                   arabic_multi_dialect_text_corpora
# 2                                          arap_tweet
# 3                   ldc_ara_dialect_eng_para_2012_t09
# 4                          ldc_arb_gulf_cttr_2006_t15
# 5                          ldc_arb_iraq_cttr_2006_t16
# 6                           ldc_arb_lev_cttr_2007_t01
# 7                             ldc_bab_arabic_2005_s08
# 8                             ldc_bab_arabic_2005_s08
# 9   ldc_bolt_sms_chat_ara_src_transliteration_2017...
# 10            ldc_callhome_ara_transcr_suppl_2002_t38
# 11                     ldc_cts_lev_ara_td5_t_2006_t07
# 12                      ldc_cts_levarabic_td_2005_s14
# 13                            ldc_la_cts_ann_2007_t04
# 14                                 madar_shared_task1
# 15                                 madar_shared_task2
# 16                                madar_corpus6_extra
# 17     multi_dialect_multi_genre_informal_corpus_news
# 18  multi_dialect_multi_genre_informal_corpus_twitter
# 19                 ldc_callhome_arabic_trans_1997_t19
# 20                      multi_dialect_parallel_corpus
# 21                                               nadi
# 22                                              padic
# 23                                               qadi
# 24                                            youdacc
# 25                                               suar
# 26                                             curras
# 27                                              gumar
#
#                                data_annotation_method  \
# 0                      ['mechanical_turk_annotators']
# 1                                      ['word_level']
# 2                                      ['user_level']
# 3                      ['mechanical_turk_annotators']
# 4                                      ['user_level']
# 5                                      ['user_level']
# 6                                      ['user_level']
# 7                                      ['user_level']
# 8                                      ['user_level']
# 9                                      ['user_level']
# 10                                     ['user_level']
# 11                                     ['user_level']
# 12                                     ['user_level']
# 13                                     ['user_level']
# 14                             ['manual_translation']
# 15                                     ['user_level']
# 16                             ['manual_translation']
# 17                     ['mechanical_turk_annotators']
# 18                     ['mechanical_turk_annotators']
# 19                                     ['user_level']
# 20                             ['manual_translation']
# 21                                     ['user_level']
# 22                             ['manual_translation']
# 23                                     ['user_level']
# 24                                     ['user_level']
# 25  ['speech_transcript', 'manual_search', 'inform...
# 26                                  ['manual_search']
# 27                                 ['document_level']
#
#                                           data_source  \
# 0                                   ['news_comments']
# 1                                       ['web_mixed']
# 2                                         ['twitter']
# 3                                       ['web_mixed']
# 4                               ['speech_transcript']
# 5                               ['speech_transcript']
# 6                               ['speech_transcript']
# 7                               ['speech_transcript']
# 8                               ['speech_transcript']
# 9                                             ['sms']
# 10                              ['speech_transcript']
# 11                              ['speech_transcript']
# 12                              ['speech_transcript']
# 13                              ['speech_transcript']
# 14                                  ['travel_domain']
# 15                                        ['twitter']
# 16                                  ['travel_domain']
# 17                                  ['news_comments']
# 18                                        ['twitter']
# 19                                    ['song_lyrics']
# 20                                      ['ldc_mixed']
# 21                                        ['twitter']
# 22                              ['speech_transcript']
# 23                                        ['twitter']
# 24                               ['youtube_comments']
# 25  ['youtube_transcript', 'blog', 'forum', 'whats...
# 26                                      ['web_mixed']
# 27                                    ['forum_novel']
#
#                                                source lexicon_corpus  \
# 0   https://www.cis.upenn.edu/~ccb/data/AOC-dialec...         corpus
# 1   http://almeman.weebly.com/arabic-multi-dialect...         corpus
# 2          https://www.aclweb.org/anthology/L18-1111/         corpus
# 3            https://catalog.ldc.upenn.edu/LDC2012T09         corpus
# 4            https://catalog.ldc.upenn.edu/LDC2006T15         corpus
# 5            https://catalog.ldc.upenn.edu/LDC2006T16         corpus
# 6            https://catalog.ldc.upenn.edu/LDC2007T01         corpus
# 7           https://catalog.ldc.upenn.edu/LDC2005S08/         corpus
# 8           https://catalog.ldc.upenn.edu/LDC2005S08/         corpus
# 9            https://catalog.ldc.upenn.edu/LDC2017T07         corpus
# 10           https://catalog.ldc.upenn.edu/LDC2002T38         corpus
# 11           https://catalog.ldc.upenn.edu/LDC2006T07         corpus
# 12           https://catalog.ldc.upenn.edu/LDC2005S14         corpus
# 13           https://catalog.ldc.upenn.edu/LDC2007T04         corpus
# 14  https://camel.abudhabi.nyu.edu/madar-shared-ta...         corpus
# 15  https://camel.abudhabi.nyu.edu/madar-shared-ta...         corpus
# 16  https://camel.abudhabi.nyu.edu/madar-shared-ta...         corpus
# 17  https://github.com/ryancotterell/arabic_dialec...         corpus
# 18  https://github.com/ryancotterell/arabic_dialec...         corpus
# 19  https://www.aclweb.org/anthology/2020.lrec-1.165/         corpus
# 20         https://www.aclweb.org/anthology/L14-1435/         corpus
# 21     https://sites.google.com/view/nadi-shared-task         corpus
# 22      https://hal.archives-ouvertes.fr/hal-01718858         corpus
# 23                http://alt.qcri.org/resources/qadi/         corpus
# 24         https://www.aclweb.org/anthology/L14-1456/         corpus
# 25  https://www.sciencedirect.com/science/article/...         corpus
# 26  https://link.springer.com/article/10.1007/s105...         corpus
# 27  https://camel.abudhabi.nyu.edu/gumar/?page=pub...         corpus
#
#    split_original_manual                               list_dialect_city_id  \
# 0                 manual                                       ['msa', nan]
# 1                 manual                                              [nan]
# 2                 manual                                              [nan]
# 3                 manual                                              [nan]
# 4               original                                              [nan]
# 5               original                                              [nan]
# 6               original                                              [nan]
# 7                 manual                                              [nan]
# 8                 manual                                              [nan]
# 9               original                                              [nan]
# 10                manual                                              [nan]
# 11                manual                                              [nan]
# 12                manual                                              [nan]
# 13                manual                                              [nan]
# 14              original  ['rabat', 'msa', 'beirut', 'doha', 'cairo', 't...
# 15              original  ['msa', 'muscat', 'riyadh', 'sfax', 'damascus'...
# 16              original  ['beirut', 'doha', 'msa', 'cairo', 'tunis', 'r...
# 17                manual                                       [nan, 'msa']
# 18                manual                                              [nan]
# 19                manual                                              [nan]
# 20                manual                                       ['msa', nan]
# 21              original                                              [nan]
# 22                manual                                       [nan, 'msa']
# 23              original                                              [nan]
# 24              original                                       [nan, 'msa']
# 25                manual                                              [nan]
# 26              original                                              [nan]
# 27              original                                              [nan]
#
#                              list_dialect_province_id  \
# 0                                        ['msa', nan]
# 1                                               [nan]
# 2                                               [nan]
# 3                                               [nan]
# 4                                               [nan]
# 5             ['south_iraq', 'baghdad', 'north_iraq']
# 6                                               [nan]
# 7                                               [nan]
# 8                                               [nan]
# 9                                               [nan]
# 10                                              [nan]
# 11                                              [nan]
# 12                                              [nan]
# 13                                              [nan]
# 14  ['rabat_sale_kenitra', 'msa', 'beirut', 'ad_da...
# 15  ['msa', 'muscat', 'riyadh', 'sfax', 'damascus'...
# 16  ['beirut', 'ad_dawhah', 'msa', 'cairo', 'tunis...
# 17                                       [nan, 'msa']
# 18                                              [nan]
# 19                                              [nan]
# 20                                       ['msa', nan]
# 21  ['alexandria', 'maysan', 'oriental', 'jabal_al...
# 22                  ['annaba', nan, 'algiers', 'msa']
# 23                                              [nan]
# 24                                       [nan, 'msa']
# 25                ['gulf,najd', 'hijaz,najd', 'najd']
# 26                                              [nan]
# 27                                              [nan]
#
#                               list_dialect_country_id  \
# 0                                  ['msa', nan, 'eg']
# 1                                         [nan, 'eg']
# 2   ['tn', 'dz', 'sa', 'ae', 'lb, sy', 'ly', 'om',...
# 3                                         ['eg', nan]
# 4                                  ['ae', 'sa', 'om']
# 5                                              ['iq']
# 6                            ['jo', 'ps', 'lb', 'sy']
# 7                                               [nan]
# 8                                               [nan]
# 9                                              ['eg']
# 10                                             ['eg']
# 11                      [nan, 'lb', 'sy', 'jo', 'ps']
# 12                           ['ps', 'lb', 'jo', 'sy']
# 13          ['jo', 'lb', 'ps', 'sy', 'iq', 'ye', nan]
# 14  ['ma', 'msa', 'lb', 'qa', 'eg', 'tn', 'sy', 'y...
# 15  ['msa', 'om', 'sa', 'tn', 'sy', 'jo', 'dz', 'l...
# 16              ['lb', 'qa', 'msa', 'eg', 'tn', 'ma']
# 17                           ['eg', 'iq', 'msa', nan]
# 18                                  ['eg', nan, 'iq']
# 19  ['eg', 'sa', 'iq', 'sd', 'kw', 'lb', 'ae', 'ma...
# 20              ['msa', 'sy', 'ps', 'jo', 'eg', 'tn']
# 21  ['eg', 'iq', 'ma', 'ly', 'ae', 'mr', 'sa', 'bh...
# 22              ['dz', 'ps', 'ma', 'tn', 'sy', 'msa']
# 23  ['lb', 'jo', 'eg', 'iq', 'tn', 'kw', 'sd', 'ye...
# 24                           ['iq', nan, 'msa', 'eg']
# 25                                             ['sa']
# 26                                             ['ps']
# 27  ['gulf', 'sa', 'msa', 'kw', 'ae', 'qa', 'ye', ...
#
#                                list_dialect_region_id
# 0             ['msa', 'gulf', 'nile_basin', 'levant']
# 1         ['levant', 'gulf', 'maghreb', 'nile_basin']
# 2   ['maghreb', 'gulf', 'levant', 'nile_basin', 'g...
# 3                            ['nile_basin', 'levant']
# 4                                            ['gulf']
# 5                                            ['iraq']
# 6                                          ['levant']
# 7                                          ['levant']
# 8                                          ['levant']
# 9                                      ['nile_basin']
# 10                                     ['nile_basin']
# 11                                         ['levant']
# 12                                         ['levant']
# 13                    ['levant', 'iraq', 'gulf_aden']
# 14  ['maghreb', 'msa', 'levant', 'gulf', 'nile_bas...
# 15  ['msa', 'gulf', 'maghreb', 'levant', 'nile_bas...
# 16  ['levant', 'gulf', 'msa', 'nile_basin', 'maghr...
# 17  ['nile_basin', 'iraq', 'msa', 'levant', 'maghr...
# 18  ['nile_basin', 'levant', 'iraq', 'maghreb', 'g...
# 19  ['nile_basin', 'gulf', 'iraq', 'levant', 'magh...
# 20         ['msa', 'levant', 'nile_basin', 'maghreb']
# 21  ['nile_basin', 'iraq', 'maghreb', 'gulf', 'lev...
# 22                  ['maghreb', 'levant', nan, 'msa']
# 23  ['levant', 'nile_basin', 'iraq', 'maghreb', 'g...
# 24    ['iraq', 'gulf', 'msa', 'levant', 'nile_basin']
# 25                                           ['gulf']
# 26                                         ['levant']
# 27  ['gulf', 'msa', 'gulf_aden', 'maghreb', 'nile_...

# %%
def general_adder_to_df(df, name, count):
    lines_train = [0]*len(df)
    lines_dev = [0]*len(df)
    lines_test = [0]*len(df)
    lines_total = [0]*len(df)
    set_names = set(df['dataset_name'])
    for k in count.keys():
        if k not in set_names:
            continue
        i = df[df['dataset_name'] == k].index[0]
        lines_train[i] = count[k]['train']
        lines_test[i] = count[k]['test']
        lines_dev[i] = count[k]['dev']
        lines_total[i] = count[k]['total']
    
    df[f'{name}_train'] = lines_train
    df[f'{name}_test'] = lines_test
    df[f'{name}_dev'] = lines_dev
    df[f'{name}_total'] = lines_total
    
    return df

# %%
df = general_adder_to_df(df, 'lines_count', lines_count)
df = general_adder_to_df(df, 'word_count', word_count)
df = general_adder_to_df(df, 'char_count', char_count)
df = general_adder_to_df(df, 'unique_word_count', word_set_count)
df = general_adder_to_df(df, 'unique_char_count', char_set_count)
df
# Out:
#                                          dataset_name  \
# 0                                                 aoc
# 1                   arabic_multi_dialect_text_corpora
# 2                                          arap_tweet
# 3                   ldc_ara_dialect_eng_para_2012_t09
# 4                          ldc_arb_gulf_cttr_2006_t15
# 5                          ldc_arb_iraq_cttr_2006_t16
# 6                           ldc_arb_lev_cttr_2007_t01
# 7                             ldc_bab_arabic_2005_s08
# 8                             ldc_bab_arabic_2005_s08
# 9   ldc_bolt_sms_chat_ara_src_transliteration_2017...
# 10            ldc_callhome_ara_transcr_suppl_2002_t38
# 11                     ldc_cts_lev_ara_td5_t_2006_t07
# 12                      ldc_cts_levarabic_td_2005_s14
# 13                            ldc_la_cts_ann_2007_t04
# 14                                 madar_shared_task1
# 15                                 madar_shared_task2
# 16                                madar_corpus6_extra
# 17     multi_dialect_multi_genre_informal_corpus_news
# 18  multi_dialect_multi_genre_informal_corpus_twitter
# 19                 ldc_callhome_arabic_trans_1997_t19
# 20                      multi_dialect_parallel_corpus
# 21                                               nadi
# 22                                              padic
# 23                                               qadi
# 24                                            youdacc
# 25                                               suar
# 26                                             curras
# 27                                              gumar
#
#                                data_annotation_method  \
# 0                      ['mechanical_turk_annotators']
# 1                                      ['word_level']
# 2                                      ['user_level']
# 3                      ['mechanical_turk_annotators']
# 4                                      ['user_level']
# 5                                      ['user_level']
# 6                                      ['user_level']
# 7                                      ['user_level']
# 8                                      ['user_level']
# 9                                      ['user_level']
# 10                                     ['user_level']
# 11                                     ['user_level']
# 12                                     ['user_level']
# 13                                     ['user_level']
# 14                             ['manual_translation']
# 15                                     ['user_level']
# 16                             ['manual_translation']
# 17                     ['mechanical_turk_annotators']
# 18                     ['mechanical_turk_annotators']
# 19                                     ['user_level']
# 20                             ['manual_translation']
# 21                                     ['user_level']
# 22                             ['manual_translation']
# 23                                     ['user_level']
# 24                                     ['user_level']
# 25  ['speech_transcript', 'manual_search', 'inform...
# 26                                  ['manual_search']
# 27                                 ['document_level']
#
#                                           data_source  \
# 0                                   ['news_comments']
# 1                                       ['web_mixed']
# 2                                         ['twitter']
# 3                                       ['web_mixed']
# 4                               ['speech_transcript']
# 5                               ['speech_transcript']
# 6                               ['speech_transcript']
# 7                               ['speech_transcript']
# 8                               ['speech_transcript']
# 9                                             ['sms']
# 10                              ['speech_transcript']
# 11                              ['speech_transcript']
# 12                              ['speech_transcript']
# 13                              ['speech_transcript']
# 14                                  ['travel_domain']
# 15                                        ['twitter']
# 16                                  ['travel_domain']
# 17                                  ['news_comments']
# 18                                        ['twitter']
# 19                                    ['song_lyrics']
# 20                                      ['ldc_mixed']
# 21                                        ['twitter']
# 22                              ['speech_transcript']
# 23                                        ['twitter']
# 24                               ['youtube_comments']
# 25  ['youtube_transcript', 'blog', 'forum', 'whats...
# 26                                      ['web_mixed']
# 27                                    ['forum_novel']
#
#                                                source lexicon_corpus  \
# 0   https://www.cis.upenn.edu/~ccb/data/AOC-dialec...         corpus
# 1   http://almeman.weebly.com/arabic-multi-dialect...         corpus
# 2          https://www.aclweb.org/anthology/L18-1111/         corpus
# 3            https://catalog.ldc.upenn.edu/LDC2012T09         corpus
# 4            https://catalog.ldc.upenn.edu/LDC2006T15         corpus
# 5            https://catalog.ldc.upenn.edu/LDC2006T16         corpus
# 6            https://catalog.ldc.upenn.edu/LDC2007T01         corpus
# 7           https://catalog.ldc.upenn.edu/LDC2005S08/         corpus
# 8           https://catalog.ldc.upenn.edu/LDC2005S08/         corpus
# 9            https://catalog.ldc.upenn.edu/LDC2017T07         corpus
# 10           https://catalog.ldc.upenn.edu/LDC2002T38         corpus
# 11           https://catalog.ldc.upenn.edu/LDC2006T07         corpus
# 12           https://catalog.ldc.upenn.edu/LDC2005S14         corpus
# 13           https://catalog.ldc.upenn.edu/LDC2007T04         corpus
# 14  https://camel.abudhabi.nyu.edu/madar-shared-ta...         corpus
# 15  https://camel.abudhabi.nyu.edu/madar-shared-ta...         corpus
# 16  https://camel.abudhabi.nyu.edu/madar-shared-ta...         corpus
# 17  https://github.com/ryancotterell/arabic_dialec...         corpus
# 18  https://github.com/ryancotterell/arabic_dialec...         corpus
# 19  https://www.aclweb.org/anthology/2020.lrec-1.165/         corpus
# 20         https://www.aclweb.org/anthology/L14-1435/         corpus
# 21     https://sites.google.com/view/nadi-shared-task         corpus
# 22      https://hal.archives-ouvertes.fr/hal-01718858         corpus
# 23                http://alt.qcri.org/resources/qadi/         corpus
# 24         https://www.aclweb.org/anthology/L14-1456/         corpus
# 25  https://www.sciencedirect.com/science/article/...         corpus
# 26  https://link.springer.com/article/10.1007/s105...         corpus
# 27  https://camel.abudhabi.nyu.edu/gumar/?page=pub...         corpus
#
#    split_original_manual                               list_dialect_city_id  \
# 0                 manual                                       ['msa', nan]
# 1                 manual                                              [nan]
# 2                 manual                                              [nan]
# 3                 manual                                              [nan]
# 4               original                                              [nan]
# 5               original                                              [nan]
# 6               original                                              [nan]
# 7                 manual                                              [nan]
# 8                 manual                                              [nan]
# 9               original                                              [nan]
# 10                manual                                              [nan]
# 11                manual                                              [nan]
# 12                manual                                              [nan]
# 13                manual                                              [nan]
# 14              original  ['rabat', 'msa', 'beirut', 'doha', 'cairo', 't...
# 15              original  ['msa', 'muscat', 'riyadh', 'sfax', 'damascus'...
# 16              original  ['beirut', 'doha', 'msa', 'cairo', 'tunis', 'r...
# 17                manual                                       [nan, 'msa']
# 18                manual                                              [nan]
# 19                manual                                              [nan]
# 20                manual                                       ['msa', nan]
# 21              original                                              [nan]
# 22                manual                                       [nan, 'msa']
# 23              original                                              [nan]
# 24              original                                       [nan, 'msa']
# 25                manual                                              [nan]
# 26              original                                              [nan]
# 27              original                                              [nan]
#
#                              list_dialect_province_id  \
# 0                                        ['msa', nan]
# 1                                               [nan]
# 2                                               [nan]
# 3                                               [nan]
# 4                                               [nan]
# 5             ['south_iraq', 'baghdad', 'north_iraq']
# 6                                               [nan]
# 7                                               [nan]
# 8                                               [nan]
# 9                                               [nan]
# 10                                              [nan]
# 11                                              [nan]
# 12                                              [nan]
# 13                                              [nan]
# 14  ['rabat_sale_kenitra', 'msa', 'beirut', 'ad_da...
# 15  ['msa', 'muscat', 'riyadh', 'sfax', 'damascus'...
# 16  ['beirut', 'ad_dawhah', 'msa', 'cairo', 'tunis...
# 17                                       [nan, 'msa']
# 18                                              [nan]
# 19                                              [nan]
# 20                                       ['msa', nan]
# 21  ['alexandria', 'maysan', 'oriental', 'jabal_al...
# 22                  ['annaba', nan, 'algiers', 'msa']
# 23                                              [nan]
# 24                                       [nan, 'msa']
# 25                ['gulf,najd', 'hijaz,najd', 'najd']
# 26                                              [nan]
# 27                                              [nan]
#
#                               list_dialect_country_id  \
# 0                                  ['msa', nan, 'eg']
# 1                                         [nan, 'eg']
# 2   ['tn', 'dz', 'sa', 'ae', 'lb, sy', 'ly', 'om',...
# 3                                         ['eg', nan]
# 4                                  ['ae', 'sa', 'om']
# 5                                              ['iq']
# 6                            ['jo', 'ps', 'lb', 'sy']
# 7                                               [nan]
# 8                                               [nan]
# 9                                              ['eg']
# 10                                             ['eg']
# 11                      [nan, 'lb', 'sy', 'jo', 'ps']
# 12                           ['ps', 'lb', 'jo', 'sy']
# 13          ['jo', 'lb', 'ps', 'sy', 'iq', 'ye', nan]
# 14  ['ma', 'msa', 'lb', 'qa', 'eg', 'tn', 'sy', 'y...
# 15  ['msa', 'om', 'sa', 'tn', 'sy', 'jo', 'dz', 'l...
# 16              ['lb', 'qa', 'msa', 'eg', 'tn', 'ma']
# 17                           ['eg', 'iq', 'msa', nan]
# 18                                  ['eg', nan, 'iq']
# 19  ['eg', 'sa', 'iq', 'sd', 'kw', 'lb', 'ae', 'ma...
# 20              ['msa', 'sy', 'ps', 'jo', 'eg', 'tn']
# 21  ['eg', 'iq', 'ma', 'ly', 'ae', 'mr', 'sa', 'bh...
# 22              ['dz', 'ps', 'ma', 'tn', 'sy', 'msa']
# 23  ['lb', 'jo', 'eg', 'iq', 'tn', 'kw', 'sd', 'ye...
# 24                           ['iq', nan, 'msa', 'eg']
# 25                                             ['sa']
# 26                                             ['ps']
# 27  ['gulf', 'sa', 'msa', 'kw', 'ae', 'qa', 'ye', ...
#
#                                list_dialect_region_id  ...  char_count_dev  \
# 0             ['msa', 'gulf', 'nile_basin', 'levant']  ...               0
# 1         ['levant', 'gulf', 'maghreb', 'nile_basin']  ...               0
# 2   ['maghreb', 'gulf', 'levant', 'nile_basin', 'g...  ...               0
# 3                            ['nile_basin', 'levant']  ...               0
# 4                                            ['gulf']  ...               0
# 5                                            ['iraq']  ...               0
# 6                                          ['levant']  ...               0
# 7                                          ['levant']  ...               0
# 8                                          ['levant']  ...               0
# 9                                      ['nile_basin']  ...               0
# 10                                     ['nile_basin']  ...               0
# 11                                         ['levant']  ...               0
# 12                                         ['levant']  ...               0
# 13                    ['levant', 'iraq', 'gulf_aden']  ...               0
# 14  ['maghreb', 'msa', 'levant', 'gulf', 'nile_bas...  ...               0
# 15  ['msa', 'gulf', 'maghreb', 'levant', 'nile_bas...  ...               0
# 16  ['levant', 'gulf', 'msa', 'nile_basin', 'maghr...  ...               0
# 17  ['nile_basin', 'iraq', 'msa', 'levant', 'maghr...  ...               0
# 18  ['nile_basin', 'levant', 'iraq', 'maghreb', 'g...  ...               0
# 19  ['nile_basin', 'gulf', 'iraq', 'levant', 'magh...  ...          121330
# 20         ['msa', 'levant', 'nile_basin', 'maghreb']  ...               0
# 21  ['nile_basin', 'iraq', 'maghreb', 'gulf', 'lev...  ...               0
# 22                  ['maghreb', 'levant', nan, 'msa']  ...               0
# 23  ['levant', 'nile_basin', 'iraq', 'maghreb', 'g...  ...               0
# 24    ['iraq', 'gulf', 'msa', 'levant', 'nile_basin']  ...               0
# 25                                           ['gulf']  ...               0
# 26                                         ['levant']  ...               0
# 27  ['gulf', 'msa', 'gulf_aden', 'maghreb', 'nile_...  ...               0
#
#     char_count_total  unique_word_count_train  unique_word_count_test  \
# 0                  0                        0                       0
# 1                  0                        0                       0
# 2                  0                        0                       0
# 3                  0                        0                       0
# 4                  0                        0                       0
# 5                  0                        0                       0
# 6                  0                        0                       0
# 7                  0                        0                       0
# 8                  0                        0                       0
# 9                  0                        0                       0
# 10                 0                        0                       0
# 11                 0                        0                       0
# 12                 0                        0                       0
# 13                 0                        0                       0
# 14                 0                        0                       0
# 15                 0                        0                       0
# 16                 0                        0                       0
# 17                 0                        0                       0
# 18                 0                        0                       0
# 19            668850                    11633                    2729
# 20                 0                        0                       0
# 21                 0                        0                       0
# 22                 0                        0                       0
# 23                 0                        0                       0
# 24                 0                        0                       0
# 25                 0                        0                       0
# 26                 0                        0                       0
# 27                 0                        0                       0
#
#     unique_word_count_dev  unique_word_count_total  unique_char_count_train  \
# 0                       0                        0                        0
# 1                       0                        0                        0
# 2                       0                        0                        0
# 3                       0                        0                        0
# 4                       0                        0                        0
# 5                       0                        0                        0
# 6                       0                        0                        0
# 7                       0                        0                        0
# 8                       0                        0                        0
# 9                       0                        0                        0
# 10                      0                        0                        0
# 11                      0                        0                        0
# 12                      0                        0                        0
# 13                      0                        0                        0
# 14                      0                        0                        0
# 15                      0                        0                        0
# 16                      0                        0                        0
# 17                      0                        0                        0
# 18                      0                        0                        0
# 19                   4807                    19169                    11633
# 20                      0                        0                        0
# 21                      0                        0                        0
# 22                      0                        0                        0
# 23                      0                        0                        0
# 24                      0                        0                        0
# 25                      0                        0                        0
# 26                      0                        0                        0
# 27                      0                        0                        0
#
#     unique_char_count_test  unique_char_count_dev  unique_char_count_total
# 0                        0                      0                        0
# 1                        0                      0                        0
# 2                        0                      0                        0
# 3                        0                      0                        0
# 4                        0                      0                        0
# 5                        0                      0                        0
# 6                        0                      0                        0
# 7                        0                      0                        0
# 8                        0                      0                        0
# 9                        0                      0                        0
# 10                       0                      0                        0
# 11                       0                      0                        0
# 12                       0                      0                        0
# 13                       0                      0                        0
# 14                       0                      0                        0
# 15                       0                      0                        0
# 16                       0                      0                        0
# 17                       0                      0                        0
# 18                       0                      0                        0
# 19                    2729                   4807                    19169
# 20                       0                      0                        0
# 21                       0                      0                        0
# 22                       0                      0                        0
# 23                       0                      0                        0
# 24                       0                      0                        0
# 25                       0                      0                        0
# 26                       0                      0                        0
# 27                       0                      0                        0
#
# [28 rows x 30 columns]

# %%
df.to_csv('../love.tsv', sep='\t', index=False)
